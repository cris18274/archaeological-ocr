# %% [markdown]
# # 1. Preparar Entorno PaddleOCR
# Ejecuta esta celda para descargar PaddleOCR y la GPU.

# %%
# !git clone https://github.com/PaddlePaddle/PaddleOCR.git
# %cd PaddleOCR
# !pip install -r requirements.txt
# !python -m pip install paddlepaddle-gpu

# %% [markdown]
# # 2. Descargar pesos base

# %%
# !mkdir -p /content/pretrain_models
# %cd /content/pretrain_models
# !wget https://paddleocr.bj.bcebos.com/PP-OCRv4/chinese/ch_PP-OCRv4_rec_train.tar
# !tar xf ch_PP-OCRv4_rec_train.tar
# %cd /content/PaddleOCR

# %% [markdown]
# # 3. Datos y Configuración
# **ATENCIÓN:** Antes de correr la siguiente celda, comprime tu carpeta dataset local en un archivo dataset.zip y súbelo a Colab. Sube también tu custom_rec_config.yml.

# %%
# !unzip -q /content/dataset.zip -d /content/
# !mv /content/custom_rec_config.yml /content/PaddleOCR/

# %% [markdown]
# # 4. Iniciar Entrenamiento
# Esto tomará ~30 minutos.

# %%
# !python tools/train.py -c custom_rec_config.yml

# %% [markdown]
# # 5. Exportar el Modelo FInal

# %%
# !python tools/export_model.py -c custom_rec_config.yml -o Global.pretrained_model=/content/custom_models/archaeo_rec_v1/best_accuracy Global.save_inference_dir=/content/inference_model/
